# %%
from lca2rmnd.reporting import ElectricityLCAReporting
from pathlib import Path

scenario = "default"
project = "test"
years = [2020, 2030, 2040, 2050]
remind_output_folder = "../remind_data/"
methods =  [
    ('ReCiPe Midpoint (H) V1.13', 'agricultural land occupation', 'ALOP'),
    ('ReCiPe Midpoint (H) V1.13', 'climate change', 'GWP100'),
    ('ReCiPe Midpoint (H) V1.13', 'fossil depletion', 'FDP'),
    ('ReCiPe Midpoint (H) V1.13', 'freshwater ecotoxicity', 'FETPinf'),
    ('ReCiPe Midpoint (H) V1.13', 'freshwater eutrophication', 'FEP'),
    ('ReCiPe Midpoint (H) V1.13', 'human toxicity', 'HTPinf'),
    ('ReCiPe Midpoint (H) V1.13', 'ionising radiation', 'IRP_HE'),
    ('ReCiPe Midpoint (H) V1.13', 'marine ecotoxicity', 'METPinf'),
    ('ReCiPe Midpoint (H) V1.13', 'marine eutrophication', 'MEP'),
    ('ReCiPe Midpoint (H) V1.13', 'metal depletion', 'MDP'),
    ('ReCiPe Midpoint (H) V1.13', 'natural land transformation', 'NLTP'),
    ('ReCiPe Midpoint (H) V1.13', 'ozone depletion', 'ODPinf'),
    ('ReCiPe Midpoint (H) V1.13', 'particulate matter formation', 'PMFP'),
    ('ReCiPe Midpoint (H) V1.13', 'photochemical oxidant formation', 'POFP'),
    ('ReCiPe Midpoint (H) V1.13', 'terrestrial acidification', 'TAP100'),
    ('ReCiPe Midpoint (H) V1.13', 'terrestrial ecotoxicity', 'TETPinf'),
    ('ReCiPe Midpoint (H) V1.13', 'urban land occupation', 'ULOP'),
    ('ReCiPe Midpoint (H) V1.13', 'water depletion', 'WDP')
]

# %%
rep = ElectricityLCAReporting(
    scenario,
    years,
    project,
    Path(remind_output_folder),
    methods=methods
)

# %%
el_lca = rep.report_sectoral_LCA()
# Out:
# c:\Users\davidba\internalization\lca2rmnd\lca2rmnd\reporting.py:534: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .sum()
# c:\Users\davidba\internalization\lca2rmnd\lca2rmnd\reporting.py:534: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .sum()

# %%
el_lca
# Out:
#                                                                    value  \
# Year Region Method
# 2020 CAZ    (ReCiPe Midpoint (H) V1.13, agricultural land o...  1.578029
#             (ReCiPe Midpoint (H) V1.13, climate change, GWP...  1.578029
#             (ReCiPe Midpoint (H) V1.13, fossil depletion, FDP)  1.578029
#             (ReCiPe Midpoint (H) V1.13, freshwater ecotoxic...  1.578029
#             (ReCiPe Midpoint (H) V1.13, freshwater eutrophi...  1.578029
# ...                                                                  ...
# 2050 USA    (ReCiPe Midpoint (H) V1.13, photochemical oxida...  3.416783
#             (ReCiPe Midpoint (H) V1.13, terrestrial acidifi...  3.416783
#             (ReCiPe Midpoint (H) V1.13, terrestrial ecotoxi...  3.416783
#             (ReCiPe Midpoint (H) V1.13, urban land occupati...  3.416783
#             (ReCiPe Midpoint (H) V1.13, water depletion, WDP)   3.416783
#
#                                                                                                       Market  \
# Year Region Method
# 2020 CAZ    (ReCiPe Midpoint (H) V1.13, agricultural land o...     market group for electricity, low voltage
#             (ReCiPe Midpoint (H) V1.13, climate change, GWP...     market group for electricity, low voltage
#             (ReCiPe Midpoint (H) V1.13, fossil depletion, FDP)     market group for electricity, low voltage
#             (ReCiPe Midpoint (H) V1.13, freshwater ecotoxic...     market group for electricity, low voltage
#             (ReCiPe Midpoint (H) V1.13, freshwater eutrophi...     market group for electricity, low voltage
# ...                                                                                                      ...
# 2050 USA    (ReCiPe Midpoint (H) V1.13, photochemical oxida...  market group for electricity, medium voltage
#             (ReCiPe Midpoint (H) V1.13, terrestrial acidifi...  market group for electricity, medium voltage
#             (ReCiPe Midpoint (H) V1.13, terrestrial ecotoxi...  market group for electricity, medium voltage
#             (ReCiPe Midpoint (H) V1.13, urban land occupati...  market group for electricity, medium voltage
#             (ReCiPe Midpoint (H) V1.13, water depletion, WDP)   market group for electricity, medium voltage
#
#                                                                    score  \
# Year Region Method
# 2020 CAZ    (ReCiPe Midpoint (H) V1.13, agricultural land o...  0.052073
#             (ReCiPe Midpoint (H) V1.13, climate change, GWP...  0.088362
#             (ReCiPe Midpoint (H) V1.13, fossil depletion, FDP)  0.034689
#             (ReCiPe Midpoint (H) V1.13, freshwater ecotoxic...  0.023911
#             (ReCiPe Midpoint (H) V1.13, freshwater eutrophi...  0.000015
# ...                                                                  ...
# 2050 USA    (ReCiPe Midpoint (H) V1.13, photochemical oxida...  0.000189
#             (ReCiPe Midpoint (H) V1.13, terrestrial acidifi...  0.000130
#             (ReCiPe Midpoint (H) V1.13, terrestrial ecotoxi...  0.000017
#             (ReCiPe Midpoint (H) V1.13, urban land occupati...  0.004948
#             (ReCiPe Midpoint (H) V1.13, water depletion, WDP)   0.000885
#
#                                                                 score_direct  \
# Year Region Method
# 2020 CAZ    (ReCiPe Midpoint (H) V1.13, agricultural land o...  5.034320e-02
#             (ReCiPe Midpoint (H) V1.13, climate change, GWP...  7.462741e-02
#             (ReCiPe Midpoint (H) V1.13, fossil depletion, FDP)  0.000000e+00
#             (ReCiPe Midpoint (H) V1.13, freshwater ecotoxic...  1.754897e-06
#             (ReCiPe Midpoint (H) V1.13, freshwater eutrophi...  2.943315e-09
# ...                                                                      ...
# 2050 USA    (ReCiPe Midpoint (H) V1.13, photochemical oxida...  1.594064e-05
#             (ReCiPe Midpoint (H) V1.13, terrestrial acidifi...  1.005674e-05
#             (ReCiPe Midpoint (H) V1.13, terrestrial ecotoxi...  4.512609e-08
#             (ReCiPe Midpoint (H) V1.13, urban land occupati...  2.817666e-07
#             (ReCiPe Midpoint (H) V1.13, water depletion, WDP)   7.311552e-04
#
#                                                                  total_score  \
# Year Region Method
# 2020 CAZ    (ReCiPe Midpoint (H) V1.13, agricultural land o...  2.300842e+10
#             (ReCiPe Midpoint (H) V1.13, climate change, GWP...  3.904254e+10
#             (ReCiPe Midpoint (H) V1.13, fossil depletion, FDP)  1.532719e+10
#             (ReCiPe Midpoint (H) V1.13, freshwater ecotoxic...  1.056517e+10
#             (ReCiPe Midpoint (H) V1.13, freshwater eutrophi...  6.678324e+06
# ...                                                                      ...
# 2050 USA    (ReCiPe Midpoint (H) V1.13, photochemical oxida...  1.803996e+08
#             (ReCiPe Midpoint (H) V1.13, terrestrial acidifi...  1.247631e+08
#             (ReCiPe Midpoint (H) V1.13, terrestrial ecotoxi...  1.613140e+07
#             (ReCiPe Midpoint (H) V1.13, urban land occupati...  4.733729e+09
#             (ReCiPe Midpoint (H) V1.13, water depletion, WDP)   8.470268e+08
#
#                                                                 total_score_direct
# Year Region Method
# 2020 CAZ    (ReCiPe Midpoint (H) V1.13, agricultural land o...        2.224406e+10
#             (ReCiPe Midpoint (H) V1.13, climate change, GWP...        3.297399e+10
#             (ReCiPe Midpoint (H) V1.13, fossil depletion, FDP)        0.000000e+00
#             (ReCiPe Midpoint (H) V1.13, freshwater ecotoxic...        7.753980e+05
#             (ReCiPe Midpoint (H) V1.13, freshwater eutrophi...        1.300499e+03
# ...                                                                            ...
# 2050 USA    (ReCiPe Midpoint (H) V1.13, photochemical oxida...        1.525040e+07
#             (ReCiPe Midpoint (H) V1.13, terrestrial acidifi...        9.621275e+06
#             (ReCiPe Midpoint (H) V1.13, terrestrial ecotoxi...        4.317209e+04
#             (ReCiPe Midpoint (H) V1.13, urban land occupati...        2.695658e+05
#             (ReCiPe Midpoint (H) V1.13, water depletion, WDP)         6.994956e+08
#
# [1728 rows x 6 columns]

# %%
el_lca.to_csv("sectoral_output.csv")
