# %%
import yaml
from premise.activity_maps import InventorySet, get_mapping
import brightway2 as bw

# %%
bw.projects.set_current("test")
db = bw.Database("ecoinvent_remind_default_2030")
len(db)
# Out:
# 31544

# %%
mapping = InventorySet(db)

# %%
filters = get_mapping("../mappings/pe2se.yml", "ecoinvent_aliases")

# %%
for tech, fltr in filter.items():
# Out:
# {'biochp': {'fltr': ['heat and power co-generation, wood chips, 6667 kW']},
#  'biodiesel': {'fltr': ['Biodiesel production, via transesterification, from palm oil, energy allocation',
#    'Biodiesel production, via transesterification, from rapeseed oil, energy allocation']},
#  'bioethl': {'fltr': ['Ethanol production, via fermentation'],
#   'mask': {'name': ['economic allocation',
#     'system expansion',
#     'corn',
#     'sorghum',
#     'sugarbeet',
#     'sugarcane',
#     'wheat grains']}},
#  'bioeths': {'fltr': ['Ethanol production, via fermentation'],
#   'mask': {'name': ['economic allocation',
#     'system expansion',
#     'wheat straw',
#     'eucalyptus',
#     'forest residues',
#     'miscanthus',
#     'poplar',
#     'switchgrass',
#     'willow']}},
#  'bioftcrec': {'fltr': ['Kerosene production, synthetic, Fischer Tropsch process, hydrogen from wood gasification, with CCS, energy allocation',
# ...

# %%
pe2se_map
# Out:
# {'biochp': {'heat and power co-generation, wood chips, 6667 kW',
#   'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014',
#   'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014, label-certified'},
#  'biodiesel': {'Biodiesel production, via transesterification, from palm oil, energy allocation',
#   'Biodiesel production, via transesterification, from rapeseed oil, energy allocation'},
#  'bioethl': {'Ethanol production, via fermentation, from eucalyptus',
#   'Ethanol production, via fermentation, from eucalyptus, with carbon capture and storage',
#   'Ethanol production, via fermentation, from forest residue, energy allocation',
#   'Ethanol production, via fermentation, from forest residue, with carbon capture and storage, energy allocation',
#   'Ethanol production, via fermentation, from miscanthus, energy allocation',
#   'Ethanol production, via fermentation, from miscanthus, with carbon capture and storage, energy allocation',
# ...
