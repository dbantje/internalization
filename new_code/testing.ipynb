# %%
from premise.data_collection import IAMDataCollection

# %%
iam_data = IAMDataCollection("remind", "default", 2030, "../remind_data", key=None)

# %%
iam_data.production_volumes
# Out:
# <xarray.DataArray 'value' (region: 13, variables: 48, year: 19)>
# array([[[5.96300000e-04, 7.60100000e-04, 7.53900000e-04, ...,
#          7.00000000e-07, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.68424000e-02, 5.46379000e-02, 5.40414000e-02, ...,
#          8.00000000e-07, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [7.14992000e+00, 5.54636670e+00, 4.93317990e+00, ...,
#          1.46478307e+01, 1.60704899e+01, 1.53692196e+01],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.74387000e-02, 5.53980000e-02, 5.47953000e-02, ...,
#          1.28798100e-01, 1.28802100e-01, 1.28802100e-01]],
#
#        [[0.00000000e+00, 1.77089000e-02, 9.65938000e-02, ...,
#          2.00000000e-07, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
from datahandling import mif_to_xarray

# %%
data = mif_to_xarray("../remind_data/remind_default.mif")

# %%
data
# Out:
# <xarray.DataArray 'value' (region: 13, variables: 2847, year: 19)>
# array([[[1.74413430e+00, 1.89253300e+00, 2.03838380e+00, ...,
#          2.50247760e+00, 2.68886940e+00, 2.28147380e+00],
#         [3.27020000e-02, 3.30378000e-02, 3.77135000e-02, ...,
#          1.80071000e-02, 1.65440000e-02, 1.37922000e-02],
#         [1.13821000e-02, 1.30176000e-02, 1.21696000e-02, ...,
#          1.31140000e-03, 1.15000000e-03, 1.10250000e-03],
#         ...,
#         [3.57020000e-03, 3.89050000e-03, 4.19300000e-03, ...,
#          5.56920000e-03, 5.14870000e-03, 4.53410000e-03],
#         [5.49645669e+02, 5.89031463e+02, 6.29269908e+02, ...,
#          1.29658049e+03, 1.33518163e+03, 1.39838618e+03],
#         [9.68051320e+00, 9.75319370e+00, 9.81175360e+00, ...,
#          1.14787171e+01, 1.13435288e+01, 1.14642511e+01]],
#
#        [[5.74305340e+00, 7.50991950e+00, 9.49800860e+00, ...,
#          9.86040800e+00, 1.05728572e+01, 9.02475400e+00],
# ...
